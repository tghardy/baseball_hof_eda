# %% [markdown]
# # Data Scraping
#
# ## Imports

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# %% [markdown]
# ## Request / Parsing

# %%
url = "https://en.wikipedia.org/wiki/List_of_members_of_the_National_Baseball_Hall_of_Fame"

# %%
r = requests.get(url, headers={"user-agent": "Baseball HoF Analysis (tghardy@byu.edu)"})

# %%
soup = BeautifulSoup(r.content)

# %% [markdown]
# Wikipedia articles tend to have a lot of tables on them and it doesn't always cooperate with bs4.find_all(). But, I know that the 3rd table on the page is what we're looking for (and this can be sorted out easily with trial and error).

# %%
tables = soup.find_all("table")

# %%
df = pd.read_html(str(tables[2]))[0]
# Out:
# /tmp/ipykernel_725418/3783399127.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tables[2]))[0]

# %% [markdown]
# ## Wrangling

# %%
df
# Out:
#      Year               Name Primary position           Primary team  \
# 0    1936            Ty Cobb               CF         Detroit Tigers
# 1    1936     Walter Johnson                P    Washington Senators
# 2    1936  Christy Mathewson                P        New York Giants
# 3    1936          Babe Ruth               RF       New York Yankees
# 4    1936       Honus Wagner               SS     Pittsburgh Pirates
# ..    ...                ...              ...                    ...
# 346  2025        CC Sabathia                P       New York Yankees
# 347  2025      Ichiro Suzuki               RF       Seattle Mariners
# 348  2025       Billy Wagner                P         Houston Astros
# 349  2025         Dick Allen               1B  Philadelphia Phillies
# 350  2025        Dave Parker               RF     Pittsburgh Pirates
#
#         Career Induction method  Vote %   Ref.
# 0    1905–1928            BBWAA  98.23%   [10]
# 1    1907–1927            BBWAA  83.63%   [11]
# 2    1900–1916            BBWAA  90.71%   [12]
# 3    1914–1935            BBWAA  95.13%   [13]
# 4    1897–1917            BBWAA  95.13%   [14]
# ..         ...              ...     ...    ...
# 346  2001–2019            BBWAA   86.8%  [356]
# 347  2001–2019            BBWAA  99.75%  [357]
# 348  1995–2010            BBWAA   82.5%  [358]
# 349  1963–1977         VC (CLB)   81.3%  [359]
# 350  1973–1991         VC (CLB)   87.5%  [360]
#
# [351 rows x 8 columns]

# %%
df = df.rename(columns = {"Primary position": "position", "Induction method": "method", 'Vote\xa0%': "vote_percentage"})

# %%
df
# Out:
#      Year               Name position           Primary team     Career  \
# 0    1936            Ty Cobb       CF         Detroit Tigers  1905–1928
# 1    1936     Walter Johnson        P    Washington Senators  1907–1927
# 2    1936  Christy Mathewson        P        New York Giants  1900–1916
# 3    1936          Babe Ruth       RF       New York Yankees  1914–1935
# 4    1936       Honus Wagner       SS     Pittsburgh Pirates  1897–1917
# ..    ...                ...      ...                    ...        ...
# 346  2025        CC Sabathia        P       New York Yankees  2001–2019
# 347  2025      Ichiro Suzuki       RF       Seattle Mariners  2001–2019
# 348  2025       Billy Wagner        P         Houston Astros  1995–2010
# 349  2025         Dick Allen       1B  Philadelphia Phillies  1963–1977
# 350  2025        Dave Parker       RF     Pittsburgh Pirates  1973–1991
#
#        method vote_percentage   Ref.
# 0       BBWAA          98.23%   [10]
# 1       BBWAA          83.63%   [11]
# 2       BBWAA          90.71%   [12]
# 3       BBWAA          95.13%   [13]
# 4       BBWAA          95.13%   [14]
# ..        ...             ...    ...
# 346     BBWAA           86.8%  [356]
# 347     BBWAA          99.75%  [357]
# 348     BBWAA           82.5%  [358]
# 349  VC (CLB)           81.3%  [359]
# 350  VC (CLB)           87.5%  [360]
#
# [351 rows x 8 columns]

# %%
pattern = re.compile(r"(\d{4}).*\n*.*\n*.*\n*.*(\d{4})") # Scary pattern but it fixes really annoying data
df[["career_start", "career_end"]]= df["Career"].str.extract(pattern)

# %%
df=df.drop(["Ref.", "Career"], axis = 1)

# %%
df["vote_percentage"] = df["vote_percentage"].str.replace("%", "")

# %%
df["vote_percentage"] = df["vote_percentage"].apply(lambda x: np.nan if "—" in x else x ).astype(float)

# %%
df
# Out:
#      Year               Name position           Primary team    method  \
# 0    1936            Ty Cobb       CF         Detroit Tigers     BBWAA
# 1    1936     Walter Johnson        P    Washington Senators     BBWAA
# 2    1936  Christy Mathewson        P        New York Giants     BBWAA
# 3    1936          Babe Ruth       RF       New York Yankees     BBWAA
# 4    1936       Honus Wagner       SS     Pittsburgh Pirates     BBWAA
# ..    ...                ...      ...                    ...       ...
# 346  2025        CC Sabathia        P       New York Yankees     BBWAA
# 347  2025      Ichiro Suzuki       RF       Seattle Mariners     BBWAA
# 348  2025       Billy Wagner        P         Houston Astros     BBWAA
# 349  2025         Dick Allen       1B  Philadelphia Phillies  VC (CLB)
# 350  2025        Dave Parker       RF     Pittsburgh Pirates  VC (CLB)
#
#      vote_percentage career_start career_end
# 0              98.23         1905       1928
# 1              83.63         1907       1927
# 2              90.71         1900       1916
# 3              95.13         1914       1935
# 4              95.13         1897       1917
# ..               ...          ...        ...
# 346            86.80         2001       2019
# 347            99.75         2001       2019
# 348            82.50         1995       2010
# 349            81.30         1963       1977
# 350            87.50         1973       1991
#
# [351 rows x 8 columns]

# %%
df.to_csv("baseball_hof.csv", index=False)
